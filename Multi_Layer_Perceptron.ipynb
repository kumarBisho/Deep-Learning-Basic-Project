# %%
import tensorflow as tf
# Out:
# 2024-07-03 11:39:16.388831: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-07-03 11:39:16.440886: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-07-03 11:39:16.441651: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-07-03 11:39:17.334640: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
import numpy as np

# %%
from tensorflow.keras.models import Sequential

# %%
from tensorflow.keras.layers import Flatten

# %%
from tensorflow.keras.layers import Dense

# %%
from tensorflow.keras.layers import Activation

# %%
import matplotlib.pyplot as plt

# %%
(x_train,y_train),(x_test,y_test)=tf.keras.datasets.mnist.load_data()

# %%
x_train.shape
# Out:
# (60000, 28, 28)

# %%
x_train=x_train.astype('float32')
x_test=x_test.astype('float32')

# %%
gray_scale=255
x_train/=gray_scale
x_test/=gray_scale

# %%
fig,ax= plt.subplots(5,10)
k=100
for i in range(5):
    for j in range(10):
        ax[i][j].imshow(x_train[k].reshape(28,28),aspect='auto')
        k+=1
        
plt.show()

# %%
model=Sequential([
    Flatten(input_shape=(28,28)),
    Dense(256,activation='sigmoid'),
    Dense(256,activation='sigmoid'),
    Dense(10,activation='sigmoid')
])

# %%
model

# %%
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit(x_train,y_train,epochs=10,batch_size=2000,validation_split=0.2)
# Out:
# Epoch 1/10
# 2024-07-03 12:45:22.396194: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 150528000 exceeds 10% of free system memory.
# 24/24 [==============================] - 1s 27ms/step - loss: 2.1184 - accuracy: 0.3914 - val_loss: 1.7497 - val_accuracy: 0.6348
# Epoch 2/10
# 24/24 [==============================] - 0s 20ms/step - loss: 1.3655 - accuracy: 0.7053 - val_loss: 0.9622 - val_accuracy: 0.8000
# Epoch 3/10
# 24/24 [==============================] - 0s 20ms/step - loss: 0.7868 - accuracy: 0.8217 - val_loss: 0.5960 - val_accuracy: 0.8662
# Epoch 4/10
# 24/24 [==============================] - 1s 25ms/step - loss: 0.5398 - accuracy: 0.8722 - val_loss: 0.4416 - val_accuracy: 0.8938
# Epoch 5/10
# 24/24 [==============================] - 1s 21ms/step - loss: 0.4253 - accuracy: 0.8923 - val_loss: 0.3667 - val_accuracy: 0.9053
# Epoch 6/10
# 24/24 [==============================] - 1s 21ms/step - loss: 0.3649 - accuracy: 0.9031 - val_loss: 0.3260 - val_accuracy: 0.9118
# Epoch 7/10
# 24/24 [==============================] - 1s 23ms/step - loss: 0.3287 - accuracy: 0.9101 - val_loss: 0.2991 - val_accuracy: 0.9178
# Epoch 8/10
# 24/24 [==============================] - 0s 21ms/step - loss: 0.3033 - accuracy: 0.9160 - val_loss: 0.2803 - val_accuracy: 0.9215
# Epoch 9/10
# 24/24 [==============================] - 0s 20ms/step - loss: 0.2840 - accuracy: 0.9197 - val_loss: 0.2644 - val_accuracy: 0.9256
# Epoch 10/10
# 24/24 [==============================] - 0s 20ms/step - loss: 0.2676 - accuracy: 0.9243 - val_loss: 0.2524 - val_accuracy: 0.9285

# %%
results=model.evaluate(x_test,y_test,verbose=0)
print("result ",results)
# Out:
# result  [0.25649261474609375, 0.9257000088691711]
